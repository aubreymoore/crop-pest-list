# %%
import bleach
import re

# %%
# Read HTML into a string
with open('list.html') as f:
    content = f.read()

# %%
# Use bleach to remove HTML tags
content = bleach.clean(content, tags=[], strip=True)

# Convert content to a list of strings
content = content.splitlines()

# %% [markdown]
# ### Slice out the Data We want
#
# Direct examination of the **list.html** indicates that the data we want is contained in a block of lines where:
#
# - the first line in the block is the last line in the document which contains the word **Agave**
# - the last line in the block is the last line in the document which contains **M=x**

# %%
for i, s in enumerate(content):
    if 'Agave' in s:
        first_line = i
    if 'M=x' in s:
        last_line = i

# Select the slice we want
content = content[first_line:last_line+1]

content[0:30]
# Out:
# ['Agave (Agave sisalana)[edit]',
#  'oriental scale',
#  '(Aonidiella  orientalis  (Newstead))',
#  'Homoptera: Diaspididae',
#  'Y=x',
#  'M=x',
#  '',
#  'grey pineapple mealybug',
#  '(Dysmicoccus  neobrevipes  Beardsley)',
#  'Homoptera: Pseudococcidae',
#  'M=x',
#  '',
#  'Avocado (Persea americana)[edit]',
#  'weevil',
#  '(Trigonops  sp. )',
#  'Coleoptera: Curculionidae',
#  'B=x',
#  'Y=x',
#  'T=x',
#  'P=x',
#  'M=x',
#  '',
#  'phytorus leaf beetle',
#  '(Phytorus  lineolatus  Weise)',
#  'Coleoptera: Chrysomelidae',
#  'M=x',
#  '',
#  'tea shot-hole borer',
#  '(Xyleborus  fornicatus  Eichhoff)',
#  'Coleoptera: Scolytidae']

# %% [markdown]
# ### Generate a flat file and write it to disk.

# %%
i = 0
c = content
maxi = len(c)-1

# Initialize flatfile string with headers.
flatfile = 'crop|pest_common_name|pest_scientific_name|pest_order|pest_family|pest_distribution\n'

while i <= maxi:
    if '[edit]' in c[i]:
        crop = c[i]
        crop = crop.replace('[edit]', '')
        i = i + 1
    else:
        s = ''
        while (i <= maxi) and (c[i] != ''):
            s = s + c[i]
            if not ('=' in c[i]):
                 s = s + '|'
            i = i + 1
            
        # A bit of clean up
        s = s.replace('  ', ' ') # Get rid of double spaces
        s = s.replace(': ', '|') # Split pest order and family
        
        s = re.sub('&lt;.*?&gt;','XX',s) # Remove lingering anchor tags
        s = s.replace('XX', '|')
        
        if s != '':
            flatfile += crop + '|' + s + '\n'
            flatfile = flatfile.replace('||', '|')
        i = i + 1
        
# Write flatfile to disk
with open("crop-pest.csv", "w") as f:
    f.write(flatfile)

# %% [markdown]
# ### Read lines from disk and check that each tine contains 6 fiedls (5 '|'s)

# %%
# Read flatfile from disk
with open("crop-pest.csv", "r") as f:
    ff = f.readlines()

# %%
for i, s in enumerate(ff):
    n = s.count('|')
    if n != 5:
        print(i, ' ', n, ' ', s)
# Out:
# 60   9   Beans (Phaseolus)|broad mite (Polyphagotarsonemus latus (Banks)) Acari|Tarsonemidae M=xspider mite (Tetranychus tumidus) Acari|Tetranychidae M=xleaf beetle (Pagria signata) (Motschulsky) Coleoptera|Chrysomelidae M=G chinese rose beetle (Adoretus sinicus Burmeister) Coleoptera|Scarabaeidae B=x M=x bean fly|(Ophiomyia phaseoli (Tryon))|Diptera|Agromyzidae|B=xY=xT=xM=x
#
# 99   6   Beans (Phaseolus)|==Bermuda grass (Cynodon)|rhodesgrass mealybug|(Antonina graminis (Maskell))|Homoptera|Pseudococcidae|B=xT=xM=x
#
# 102   1   Betel nut, Areca|
#
# 127   2   Betel nut, Areca|Back to Crop List|
#
# 366   4   Cycads, Cycas|caterpillar|(Chilades pandava )|Lepidoptera:Laecinidae|M=S

# %% [markdown]
# ### Great!!! We only have 5 problem lines so let's fix them here.

# %%
new = [] # New records to replace problem records
removal_list = [] # Indices of records to be removed
removal_list.append(0) # Add header row to removal list; will add this after sorting

# Replace ff[60] with:
removal_list.append(60)
new.append('Beans (Phaseolus)|broad mite (Polyphagotarsonemus latus (Banks)) Acari|Tarsonemidae M=x')
new.append('Beans (Phaseolus)|spider mite (Tetranychus tumidus) Acari|Tetranychidae M=x')
new.append('Beans (Phaseolus)|leaf beetle (Pagria signata) (Motschulsky) Coleoptera|Chrysomelidae M=G')
new.append('Beans (Phaseolus)|chinese rose beetle (Adoretus sinicus Burmeister) Coleoptera|Scarabaeidae B=x M=x') 
new.append('Beans (Phaseolus)|bean fly|(Ophiomyia phaseoli (Tryon))|Diptera|Agromyzidae|B=xY=xT=xM=x')

# Replace ff[99] with:
removal_list.append(99)
new.append('Bermuda grass (Cynodon)|\
rhodesgrass mealybug|Antonina graminis (Maskell)|Homoptera|Pseudococcidae|B=xT=xM=x')

# Replace ff[100] with:
removal_list.append(100)
new.append('Bermuda grass (Cynodon)|\
grass leaf-folder|(Marasmia venilialis (Walker))|Lepidoptera|Pyralidae|M=G')

# Replace ff[101] with:
removal_list.append(101)         
new.append('Bermuda grass (Cynodon)|lawn armyworm|(Spodoptera mauritia Guenée)|Lepidoptera|Noctuidae|M=x')

# Delete 102, 127
removal_list.append(102)
removal_list.append(127)

# Replace ff[366] with:
removal_list.append(366)
new.append('Cycads, Cycas|caterpillar|(Chilades pandava )|Lepidoptera|Lycaenidae|M=S')
           
for i, s in enumerate(ff):
    if not (i in removal_list):
           new.append(s)

new = sorted(new)
new.insert(0, ff[0])

with open('crop-pest.csv', mode='wt', encoding='utf-8') as myfile:
    myfile.write('\n'.join(new))

# %% [markdown]
# ### Let's load the data into a Pandas data frame

# %%
import pandas as pd
df = pd.read_csv('crop-pest.csv', sep='|', header=0)

# Remove parentheses around pest_scientific_name
for i, s in enumerate(df.pest_scientific_name):
    s = re.sub('^\(', '', s)
    s = re.sub('\)$', '', s)
    df.pest_scientific_name[i] = s
    
df.pest_scientific_name
df.to_csv('crop-pest.csv', index=False)
df
# Out:
#                                        crop         pest_common_name  \
# 0                    Agave (Agave sisalana)  grey pineapple mealybug
# 1                    Agave (Agave sisalana)           oriental scale
# 2                Avocado (Persea americana)            coconut scale
# 3                Avocado (Persea americana)    egyptian fluted scale
# 4                Avocado (Persea americana)        florida wax scale
# 5                Avocado (Persea americana)            latania scale
# 6                Avocado (Persea americana)         long brown scale
# 7                Avocado (Persea americana)     long-tailed mealybug
# 8                Avocado (Persea americana)                melon fly
# 9                Avocado (Persea americana)               palm scale
# 10               Avocado (Persea americana)     phytorus leaf beetle
# 11               Avocado (Persea americana)         redbanded thrips
# 12               Avocado (Persea americana)                    scale
# 13               Avocado (Persea americana)         seychelles scale
# 14               Avocado (Persea americana)      tea shot-hole borer
# 15               Avocado (Persea americana)        tessellated scale
# 16               Avocado (Persea americana)                   weevil
# 17                         Bamboo (Bambusa)          bamboo longhorn
# 18                         Bamboo (Bambusa)             bamboo scale
# 19                         Bamboo (Bambusa)             bamboo scale
# 20                         Bamboo (Bambusa)             bamboo scale
# 21                         Bamboo (Bambusa)             bamboo scale
# 22                         Bamboo (Bambusa)             bamboo scale
# 23                         Bamboo (Bambusa)             bamboo scale
# 24                         Bamboo (Bambusa)            chafer beetle
# 25                         Bamboo (Bambusa)                    mirid
# 26                            Banana (Musa)             banana aphid
# 27                            Banana (Musa)       banana corm weevil
# 28                            Banana (Musa)        banana leafroller
# 29                            Banana (Musa)        banana root borer
# ..                                      ...                      ...
# 919         Tomato, Lycopersicon esculentum      tobacco flea beetle
# 920         Tomato, Lycopersicon esculentum               tomato bug
# 921         Tomato, Lycopersicon esculentum             turnip aphid
# 922         Tomato, Lycopersicon esculentum      vegetable leafminer
# 923             Tropical almond, Terminalia      chinese rose beetle
# 924             Tropical almond, Terminalia        kirkaldy whitefly
# 925             Tropical almond, Terminalia           lilac mealybug
# 926             Tropical almond, Terminalia                     moth
# 927             Tropical almond, Terminalia      myrobalan butterfly
# 928             Tropical almond, Terminalia              nigra scale
# 929             Tropical almond, Terminalia       ochrosia fruit fly
# 930             Tropical almond, Terminalia     phytorus leaf beetle
# 931             Tropical almond, Terminalia         redbanded thrips
# 932             Tropical almond, Terminalia                   weevil
# 933             Tropical almond, Terminalia                   weevil
# 934  Wing bean, Psophocarpus tetragonalubus             cowpea aphid
# 935  Wing bean, Psophocarpus tetragonalubus           vegetable mite
# 936                         Yams, Dioscorea           cacao armyworm
# 937                         Yams, Dioscorea          citrus mealybug
# 938                         Yams, Dioscorea            coconut scale
# 939                         Yams, Dioscorea      cucurbit leafroller
# 940                         Yams, Dioscorea      green garden looper
# 941                         Yams, Dioscorea            latania scale
# 942                         Yams, Dioscorea          melia tortricid
# 943                         Yams, Dioscorea                melonworm
# 944                         Yams, Dioscorea              nigra scale
# 945                         Yams, Dioscorea             rice cutworm
# 946                         Yams, Dioscorea              spider mite
# 947                         Yams, Dioscorea              spider mite
# 948                         Yams, Dioscorea            yam hawk moth
#
#                              pest_scientific_name    pest_order  \
# 0               Dysmicoccus neobrevipes Beardsley     Homoptera
# 1                Aonidiella orientalis (Newstead)     Homoptera
# 2                  Aspidiotus destructor Signoret     Homoptera
# 3                     Icerya aegyptiaca (Douglas)     Homoptera
# 4                Ceroplastes floridensis Comstock     Homoptera
# 5                Hemiberlesia lataniae (Signoret)     Homoptera
# 6                       Coccus longulus (Douglas)     Homoptera
# 7    Pseudococcus longispinus (Targioni-Tozzetti)     Homoptera
# 8                     Dacus cucurbitae Coquillett       Diptera
# 9                 Hemiberlesia palmae (Cockerell)     Homoptera
# 10                      Phytorus lineolatus Weise    Coleoptera
# 11              Selenothrips rubrocinctus (Giard)  Thysanoptera
# 12                   Aspidiotus spinosus Comstock     Homoptera
# 13                 Icerya seychellarum (Westwood)     Homoptera
# 14                  Xyleborus fornicatus Eichhoff    Coleoptera
# 15            Eucalymnatus tessellatus (Signoret)     Homoptera
# 16                                 Trigonops sp.     Coleoptera
# 17                    Chlorophorus annularis (F.)    Coleoptera
# 18            Asterolecanium bambusae (Boisduval)     Homoptera
# 19                 Asterolecanium coronatum Green     Homoptera
# 20            Asterolecanium miliaris (Boisduval)     Homoptera
# 21     Asterolecanium pseudolanceolatum Takahashi     Homoptera
# 22            Asterolecanium pseudomiliaris Green     Homoptera
# 23                  Asterolecanium robustum Green     Homoptera
# 24                   Anomala sulcatula Burmeister    Coleoptera
# 25             Pseudoloxops bifasciatus (Usinger)     Hemiptera
# 26               Pentalonia nigronervosa Coquerel     Homoptera
# 27                  Polytus mellerborgi (Boheman)    Coleoptera
# 28                            Erionota thrax (L.)   Lepidoptera
# 29                 Cosmopolites sordidus (Germar)    Coleoptera
# ..                                            ...           ...
# 919              Epitrix hirtipennis (Melsheimer)    Coleoptera
# 920                   Cyrtopeltis tenuis (Reuter)     Hemiptera
# 921                 Lipaphis erysimi (Kaltenbach)     Homoptera
# 922                   Liriomyza sativae Blanchard       Diptera
# 923                   Adoretus sinicus Burmeister    Coleoptera
# 924              Dialeurodes kirkaldyi (Kotinsky)     Homoptera
# 925             Planococcus lilacinus (Cockerell)     Homoptera
# 926                            Anua coronata (F.)   Lepidoptera
# 927                      Badamia exclamationis F.   Lepidoptera
# 928                 Parasaissetia nigra (Nietner)     Homoptera
# 929                       Dacus ochrosiae Malloch       Diptera
# 930                     Phytorus lineolatus Weise    Coleoptera
# 931             Selenothrips rubrocinctus (Giard)  Thysanoptera
# 932                                Trigonops sp.     Coleoptera
# 933                  Trigonops vulgaris Zimmerman    Coleoptera
# 934                         Aphis craccivora Koch     Homoptera
# 935              Tetranychus neocaledonicus André         Acari
# 936                    Tiracola plagiata (Walker)   Lepidoptera
# 937                     Planococcus citri (Risso)     Homoptera
# 938                Aspidiotus destructor Signoret     Homoptera
# 939                   Diaphania indica (Saunders)   Lepidoptera
# 940                Chrysodeixis chalcites (Esper)   Lepidoptera
# 941              Hemiberlesia lataniae (Signoret)     Homoptera
# 942                       Adoxophyes melia Clarke   Lepidoptera
# 943                      Diaphania hyalinata (L.)   Lepidoptera
# 944                 Parasaissetia nigra (Nietner)     Homoptera
# 945                        Spodoptera litura (F.)   Lepidoptera
# 946                              Tetranychus sp.          Acari
# 947                              Tetranychus sp.          Acari
# 948                       Theretra nessus (Drury)   Lepidoptera
#
#           pest_family   pest_distribution
# 0      Pseudococcidae                 M=x
# 1         Diaspididae              Y=xM=x
# 2         Diaspididae     B=xY=xT=xP=xM=x
# 3        Margarodidae     B=xY=xT=xP=xM=x
# 4            Coccidae           B=xP=xM=x
# 5         Diaspididae  B=xY=xT=xP=xK=xM=x
# 6            Coccidae              B=xM=x
# 7      Pseudococcidae                 T=?
# 8         Tephritidae                 M=x
# 9         Diaspididae  B=xY=xT=YP=xK=xM=x
# 10      Chrysomelidae                 M=x
# 11          Thripidae    B=nY=nT=nP=x?M=x
# 12        Diaspididae                 Y=x
# 13       Margarodidae              B=?Y=x
# 14         Scolytidae           B=xY=xP=x
# 15           Coccidae     B=xY=nT=xP=xK=x
# 16      Curculionidae     B=xY=xT=xP=xM=x
# 17       Cerambycidae                 M=x
# 18   Asterolecaniidae           B=xT=nM=x
# 19   Asterolecaniidae                 B=x
# 20   Asterolecaniidae           B=xP=xM=x
# 21   Asterolecaniidae                 P=?
# 22   Asterolecaniidae              P=xM=G
# 23   Asterolecaniidae           B=xP=xM=G
# 24       Scarabaeidae                 M=x
# 25            Miridae                M=RG
# 26          Aphididae  B=xY=xT=xP=xK=nM=x
# 27      Curculionidae                 M=x
# 28        Hesperiidae                 M=x
# 29      Curculionidae              P=nM=x
# ..                ...                 ...
# 919     Chrysomelidae                 M=G
# 920           Miridae        B=xT=xP=xM=x
# 921         Aphididae                 M=x
# 922       Agromyzidae                 M=G
# 923      Scarabaeidae              B=xM=x
# 924       Aleyrodidae        B=xY=xP=xM=x
# 925    Pseudococcidae                 M=G
# 926         Noctuidae                 M=G
# 927       Hesperiidae              B=nM=x
# 928          Coccidae     B=xY=xT=xK=xM=x
# 929       Tephritidae                 M=x
# 930     Chrysomelidae                 M=x
# 931         Thripidae    B=nY=nT=nP=x?M=x
# 932     Curculionidae     B=xY=xT=xP=xM=x
# 933     Curculionidae                 M=x
# 934         Aphididae     Y=xT=xP=xK=xM=x
# 935     Tetranychidae                 M=G
# 936         Noctuidae                 M=x
# 937    Pseudococcidae  B=xY=xT=xP=xK=xM=x
# 938       Diaspididae     B=xY=xT=xP=xM=x
# 939         Pyralidae              B=xM=x
# 940         Noctuidae              B=nM=x
# 941       Diaspididae  B=xY=xT=xP=xK=xM=x
# 942       Tortricidae                 M=x
# 943         Pyralidae              B=xM=x
# 944          Coccidae     B=xY=xT=xK=xM=x
# 945         Noctuidae  B=xY=?T=xP=xK=?M=x
# 946     Tetranychidae                 M=C
# 947     Tetranychidae                 M=x
# 948        Sphingidae           B=xY=xT=x
#
# [949 rows x 6 columns]

# %% [markdown]
# ### FINISHED
# To read the csv file into a Pandas data frame use:
#
#     df = pd.read_csv('crop-pest.csv', header=0)
